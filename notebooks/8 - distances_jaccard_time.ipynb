# %%
import pandas as pd
import numpy as np
from sklearn.metrics import jaccard_score
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('mode.chained_assignment', None)

# Disable future warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

def weighted_jaccard_similarity(matrix1, matrix2):
    """
    Compute the Weighted Jaccard Similarity between two adjacency matrices.
    """
    # Ensure matrices are numpy arrays for element-wise operations
    matrix1 = np.array(matrix1)
    matrix2 = np.array(matrix2)

    # Calculate the minimum (intersection) and maximum (union) for each element
    min_matrix = np.minimum(matrix1, matrix2)
    max_matrix = np.maximum(matrix1, matrix2)

    # Sum the weights for intersection and union
    intersection_weight_sum = np.sum(min_matrix)
    union_weight_sum = np.sum(max_matrix)

    # Compute the similarity
    similarity = intersection_weight_sum / union_weight_sum if union_weight_sum != 0 else 0
    return similarity


def prepare_edge_list(edge1, edge2):

    matrix1 = edge1.pivot(index ='source', columns='target', values='weight')
    matrix1 = matrix1.fillna(0)

    # Add the row[i]/col[i] when there is not information
    all_occupations = list(matrix1.index)

    # Add missing occupations
    for occupation in all_occupations:
        if occupation not in matrix1.columns:
            matrix1[occupation] = 0.0  # Add new column with zeros

    # Resetting the diagonal values to 0 for existing occupations (if necessary)
    for occupation in matrix1.columns:
        matrix1.at[occupation, occupation] = 0.0

    matrix1 = matrix1.fillna(0)

    matrix2 = edge2.pivot(index ='source', columns='target', values='weight')
    matrix2 = matrix2.fillna(0)

        # Add the row[i]/col[i] when there is not information
    all_occupations = list(matrix2.index)

    # Add missing occupations
    for occupation in all_occupations:
        if occupation not in matrix2.columns:
            matrix2[occupation] = 0.0  # Add new column with zeros

    # Resetting the diagonal values to 0 for existing occupations (if necessary)
    for occupation in matrix2.columns:
        matrix2.at[occupation, occupation] = 0.0

    matrix2 = matrix2.fillna(0)

    labels1 = list(matrix1.index)
    labels2 = list(matrix2.index)
    common_labels = set(labels1).intersection(set(labels2))

    matrix1 = matrix1[common_labels]
    matrix1 = matrix1.reset_index()
    matrix1 = matrix1[matrix1['source'].isin(common_labels)]
    matrix1 = matrix1.set_index('source')

    matrix2 = matrix2[common_labels]
    matrix2 = matrix2.reset_index()
    matrix2 = matrix2[matrix2['source'].isin(common_labels)]
    matrix2 = matrix2.set_index('source')

    matrix1 = matrix1.loc[common_labels, common_labels]
    matrix2 = matrix2.loc[common_labels, common_labels]

    return matrix1, matrix2


def compute_jaccar_simlarity(matrix1, matrix2):

    def replace_with_one(x):
        return 1 if x >= 1 else x

    matrix1_1 = matrix1.applymap(replace_with_one)
    matrix2_1 = matrix2.applymap(replace_with_one)

    score = jaccard_score(matrix1_1.to_numpy(), matrix2_1.to_numpy(), average='weighted')
    weighted_score = weighted_jaccard_similarity(matrix1, matrix2)

    return score, weighted_score

# %%
def weighted_jaccard(matrix1, matrix2):

    # Ensure matrices are numpy arrays for element-wise operations
    matrix1 = np.array(matrix1)
    matrix2 = np.array(matrix2)

    # Calculate the minimum (intersection) and maximum (union) for each element
    min_matrix = np.minimum(matrix1, matrix2)
    max_matrix = np.maximum(matrix1, matrix2)

    # Sum the weights for intersection and union
    intersection_weight_sum = np.sum(min_matrix)
    union_weight_sum = np.sum(max_matrix)


    return intersection_weight_sum / union_weight_sum if union_weight_sum != 0 else 0

# %%
import glob

main_path = 'edges_list_filtered/'
paths = glob.glob(f'{main_path}*')

datasets ={}
# correct_list = ['average_edges_list_global_thresh', 'average_edges_list']
# correct_list = ['german_world_1', 'german_world_2']
# correct_list = ['france_1', 'france_2']
# correct_list = ['arabic_1', 'arabic_2']


for path in paths:

    mat = pd.read_csv(path, index_col=[0])
    mat = mat[['source', 'target', 'weight']]
    name = path.split(main_path)[1].split('.csv')[0]
    # if name in correct_list:
    #     datasets[name] = mat

    datasets[name] = mat


print(list(datasets.keys()))
# Out:
# ['arabic_world', 'Italy', 'france_1', 'europe_before_1700', 'france_2', 'Ancient Mediterranean', 'indian_world', 'MENA', 'chinese_world', 'non_europe_before_1700', 'France', 'average_edges_list', 'global_before_1700_women', 'German world', 'japan_world', 'Nordic countries', 'Asia', 'greek_world', 'Eastern Europe', 'arabic_1', 'average_edges_list_global_thresh', 'Low countries', 'arabic_2', 'British Islands', 'german_world_2', 'latin_world', 'german_world_1', 'global_1600_1700', 'global_before_1600', 'Iberian Peninsula']

# %%
datasets['average_edges_list']
# Out:
#                   source          target  weight
# 35            astronomer   mathematician  215.42
# 92         mathematician      astronomer  215.42
# 122          philosopher      theologian  117.64
# 141           theologian     philosopher  117.64
# 121          philosopher   mathematician  114.17
# ..                   ...             ...     ...
# 52             economist         chemist    0.03
# 98         meteorologist       historian    0.02
# 78             geologist      theologian    0.01
# 108       paleontologist      geographer    0.01
# 126  political scientist  anthropologist    0.01
#
# [150 rows x 3 columns]

# %%
# Create an empty DataFrame to store the ARI values
ari_df = pd.DataFrame(columns=['Dataset 1', 'Dataset 2', 'metric'])

# Iterate over pairs of datasets and compute the ARI
for dataset1_name, dataset1 in datasets.items():
    for dataset2_name, dataset2 in datasets.items():
        # Get the common elements based on the 'node' column

        dataset1 = dataset1[['source', 'target', 'weight']]
        # Weighted Similary
        dataset1['weight'] = (dataset1['weight'] - dataset1['weight'].min()) / (dataset1['weight'].max() - dataset1['weight'].min())

        dataset2 = dataset2[['source', 'target', 'weight']]
        dataset2['weight'] = (dataset2['weight'] - dataset2['weight'].min()) / (dataset2['weight'].max() - dataset2['weight'].min())

        matrix1, matrix2 = prepare_edge_list(dataset1, dataset2)
        matrix1, matrix2 = matrix1.to_numpy(), matrix2.to_numpy()

        score = weighted_jaccard_similarity(matrix1.flatten(), matrix2.flatten())
        print(score)
        try:
            score = round(score, 2)
        except:
            score = score
        ari_df = ari_df.append({'Dataset 1': dataset1_name, 'Dataset 2': dataset2_name, 'metric': score}, ignore_index=True)

# Print or analyze the ARI values as needed
matrix_df = ari_df.pivot(index='Dataset 1', columns='Dataset 2', values='metric')
matrix_df
# Out:
# 1.0
# 0.4393075297455346
# 0.31773240193444385
# Eastern Europe                    ...           0.55           0.53
# France                            ...           0.47           0.53
# German world                      ...           0.84           0.83
# Iberian Peninsula                 ...           0.42           0.44
# Italy                             ...           0.47           0.49
# Low countries                     ...           0.54           0.57
# MENA                              ...           0.35           0.32
# Nordic countries                  ...           0.44           0.49
# arabic_1                          ...           0.35           0.33
# arabic_2                          ...           0.29           0.29
# arabic_world                      ...           0.28           0.27
# average_edges_list                ...           0.43           0.44
# average_edges_list_global_thresh  ...           0.24           0.25
# chinese_world                     ...           0.27           0.24
# europe_before_1700                ...           0.59           0.65
# france_1                          ...           0.46           0.54
# france_2                          ...           0.43           0.45
# german_world_1                    ...            1.0           0.71
# german_world_2                    ...           0.71            1.0
# global_1600_1700                  ...           0.58           0.61
# global_before_1600                ...           0.52           0.52
# global_before_1700_women          ...           0.21           0.17
# greek_world                       ...           0.24           0.22
# indian_world                      ...           0.25           0.25
# japan_world                       ...           0.05           0.06
# latin_world                       ...           0.28           0.26
# non_europe_before_1700            ...           0.29           0.26
#
# Dataset 2                        global_1600_1700 global_before_1600  \
# Dataset 1
# Ancient Mediterranean                        0.33               0.45
# Asia                                         0.27               0.38
# British Islands                              0.61               0.58
# Eastern Europe                               0.56               0.67
# France                                       0.56               0.57
# German world                                  0.6               0.55
# Iberian Peninsula                            0.49               0.54
# Italy                                        0.66               0.73
# Low countries                                0.74               0.56
# MENA                                          0.4               0.52
# Nordic countries                             0.47               0.37
# arabic_1                                     0.37               0.49
# arabic_2                                     0.36               0.42
# arabic_world                                 0.37               0.46
# average_edges_list                           0.56               0.79
# average_edges_list_global_thresh             0.26               0.35
# chinese_world                                0.27                0.4
# europe_before_1700                           0.75               0.72
# france_1                                     0.59               0.58
# france_2                                     0.45               0.48
# german_world_1                               0.58               0.52
# german_world_2                               0.61               0.52
# global_1600_1700                              1.0               0.61
# global_before_1600                           0.61                1.0
# global_before_1700_women                     0.21                0.3
# greek_world                                   0.3               0.42
# indian_world                                 0.26               0.29
# japan_world                                  0.08               0.08
# latin_world                                  0.34               0.41
# non_europe_before_1700                       0.36               0.57
#
# Dataset 2                        global_before_1700_women greek_world  \
# Dataset 1
# Ancient Mediterranean                                0.47        0.81
# Asia                                                 0.23        0.42
# British Islands                                      0.27        0.31
# Eastern Europe                                       0.33        0.34
# France                                               0.24        0.26
# German world                                          0.2        0.24
# Iberian Peninsula                                    0.25        0.24
# Italy                                                0.29        0.41
# Low countries                                         0.2        0.28
# MENA                                                 0.33        0.46
# Nordic countries                                     0.16        0.21
# arabic_1                                             0.25        0.42
# arabic_2                                             0.33         0.4
# arabic_world                                         0.25        0.42
# average_edges_list                                   0.33        0.47
# average_edges_list_global_thresh                      0.2        0.26
# chinese_world                                        0.25        0.43
# europe_before_1700                                   0.25        0.34
# france_1                                             0.23        0.26
# france_2                                             0.26        0.24
# german_world_1                                       0.21        0.24
# german_world_2                                       0.17        0.22
# global_1600_1700                                     0.21         0.3
# global_before_1600                                    0.3        0.42
# global_before_1700_women                              1.0         0.5
# greek_world                                           0.5         1.0
# indian_world                                         0.31        0.31
# japan_world                                          0.03         0.1
# latin_world                                          0.24        0.24
# non_europe_before_1700                               0.33        0.62
#
# Dataset 2                        indian_world japan_world latin_world  \
# Dataset 1
# Ancient Mediterranean                    0.26        0.08        0.33
# Asia                                     0.41         0.1        0.19
# British Islands                          0.27        0.07        0.32
# Eastern Europe                           0.35        0.07        0.33
# France                                    0.2        0.09         0.4
# German world                             0.26        0.06        0.28
# Iberian Peninsula                        0.19         0.1        0.45
# Italy                                    0.31        0.09        0.37
# Low countries                            0.23        0.07        0.33
# MENA                                      0.4        0.06        0.26
# Nordic countries                         0.26        0.08        0.22
# arabic_1                                 0.37        0.09        0.23
# arabic_2                                 0.41         0.1        0.27
# arabic_world                             0.36        0.14        0.32
# average_edges_list                       0.33        0.08        0.36
# average_edges_list_global_thresh          0.2        0.06        0.23
# chinese_world                            0.32         0.1        0.18
# europe_before_1700                       0.27        0.09        0.37
# france_1                                  0.2        0.08         0.4
# france_2                                 0.21        0.07        0.41
# german_world_1                           0.25        0.05        0.28
# german_world_2                           0.25        0.06        0.26
# global_1600_1700                         0.26        0.08        0.34
# global_before_1600                       0.29        0.08        0.41
# global_before_1700_women                 0.31        0.03        0.24
# greek_world                              0.31         0.1        0.24
# indian_world                              1.0        0.07        0.18
# japan_world                              0.07         1.0         0.1
# latin_world                              0.18         0.1         1.0
# non_europe_before_1700                   0.32        0.08        0.27
#
# Dataset 2                        non_europe_before_1700
# Dataset 1
# Ancient Mediterranean                              0.61
# Asia                                               0.57
# British Islands                                    0.33
# Eastern Europe                                     0.46
# France                                              0.3
# German world                                       0.29
# Iberian Peninsula                                  0.32
# Italy                                              0.49
# Low countries                                      0.32
# MENA                                               0.65
# Nordic countries                                   0.26
# arabic_1                                           0.58
# arabic_2                                            0.5
# arabic_world                                       0.56
# average_edges_list                                 0.63
# average_edges_list_global_thresh                   0.29
# chinese_world                                      0.59
# europe_before_1700                                  0.4
# france_1                                            0.3
# france_2                                           0.26
# german_world_1                                     0.29
# german_world_2                                     0.26
# global_1600_1700                                   0.36
# global_before_1600                                 0.57
# global_before_1700_women                           0.33
# greek_world                                        0.62
# indian_world                                       0.32
# japan_world                                        0.08
# latin_world                                        0.27
# non_europe_before_1700                              1.0
#
# [30 rows x 30 columns]

# %%
#matrix_df.columns = ['Weighted Network', 'European Network', 'Women Network', 'Non-European Network']
#matrix_df.index = ['Weighted Network', 'European Network', 'Women Network','Non-European Network']

plt.figure(figsize=(15, 15))
#sns.heatmap(matrix_df.astype(float), cmap='Blues', annot=True, fmt=".2f", cbar=False)
sns.heatmap(matrix_df.astype(float), cmap='Blues', annot=True, fmt=".2f", 
                 cbar=False, annot_kws={"size": 14})  # Increase font size here

plt.xlabel('')
plt.ylabel('')
plt.title('Normalized Weighted Jaccard Similarity')
plt.show()
